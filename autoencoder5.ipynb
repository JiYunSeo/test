# %%
from keras.layers import Input, Dense, Conv1D, MaxPooling1D, UpSampling1D, Activation, Flatten, Dropout, LeakyReLU, BatchNormalization, Conv2DTranspose, Lambda
from keras.models import Model, Sequential
from keras import backend as K
import tensorflow as tf
import numpy as np
import random
import matplotlib.pyplot as plt
import csv
import os
from numpy import genfromtxt
# Out:
# Using TensorFlow backend.

# %%
def read_ecg(file_name):
    return genfromtxt(file_name, delimiter=',')

# %%
np_data = read_ecg('./input/clean_ecg3.csv')
np_data2 = read_ecg('./input/noise_ecg3.csv')

# %%
split_percent = 0.8

x_train = np_data[0 : int((np_data.shape[0]) * split_percent)]
x_test = np_data[int(np_data.shape[0] * split_percent): ]


xtrainn = np_data2[0 : int((np_data2.shape[0]) * split_percent)]
xtestn = np_data2[int(np_data2.shape[0] * split_percent): ]


print(x_train.shape)
print(xtrainn.shape)
print(x_test.shape)
print(xtestn.shape)
# Out:
# (6086, 1024)
# (6086, 1024)
# (1522, 1024)
# (1522, 1024)

# %%
fig, ax=plt.subplots(figsize=(15,5))
ax.plot(x_train[1000], 'b')
plt.title("clean ecg")
plt.show()

# %%
fig, ax=plt.subplots(figsize=(15,5))
ax.plot(xtrainn[1000], 'r')
plt.title("noise ecg")
plt.show()

# %%
fig, ax=plt.subplots(figsize=(15,5))
ax.plot(x_train[1000], 'r')
ax.plot(xtrainn[1000], 'b')
plt.title("clean ecg[b] + noise ecg[r]")
plt.show()

# %%
x_train_noisy = np.asarray(xtrainn)
x_test_noisy = np.asarray(xtestn)

# %%
def normalized(a, axis=-1, order=2):
    l2 = np.atleast_1d(np.linalg.norm(a, order, axis))
    l2[l2==0] = 1
    return a / np.expand_dims(l2, axis)

# %%
x_train = normalized(x_train,1)
x_test = normalized(x_test,1)
x_train_noisy = normalized(x_train_noisy,1)
x_test_noisy = normalized(x_test_noisy, 1)

# %%
fig, ax=plt.subplots(figsize=(15,5))
ax.plot(x_train[0], 'b')
plt.title("clean ecg")
plt.show()

# %%
fig, ax=plt.subplots(figsize=(15,5))
ax.plot(x_train_noisy[0], 'r')
plt.title("noise ecg")
plt.show()

# %%
fig, ax=plt.subplots(figsize=(15,5))
ax.plot(x_train[0], 'b',label='clean_ecg')
ax.plot(x_train_noisy[0], 'r',label='noise_ecg')
plt.title("clean ecg[b] + noise ecg[r]")
plt.legend()
plt.show()

# %%
x_train = x_train.reshape((x_train.shape[0],x_train.shape[1],1))
x_train_noisy = x_train_noisy.reshape((x_train_noisy.shape[0],x_train_noisy.shape[1],1))
x_test = x_test.reshape((x_test.shape[0],x_test.shape[1],1))
x_test_noisy = x_test_noisy.reshape((x_test_noisy.shape[0],x_test_noisy.shape[1],1))

# %%
print(x_train.shape)
print(x_train_noisy.shape)
print(x_test.shape)
print(x_test_noisy.shape)
# Out:
# (6086, 1024, 1)
# (6086, 1024, 1)
# (1522, 1024, 1)
# (1522, 1024, 1)

# %%
a = x_train[0]
a
# Out:
# array([[0.0333481 ],
#        [0.0333481 ],
#        [0.0333481 ],
#        ...,
#        [0.03036364],
#        [0.03036364],
#        [0.03029876]])

# %%
b = x_train_noisy[0]
b
# Out:
# array([[0.0334441 ],
#        [0.03343797],
#        [0.03344206],
#        ...,
#        [0.03065811],
#        [0.03065811],
#        [0.03058463]])

# %%
def Conv1DTranspose(input_tensor, filters, kernel_size, strides=2, activation='relu', padding='same'):
    """
        https://stackoverflow.com/a/45788699

        input_tensor: tensor, with the shape (batch_size, time_steps, dims)
        filters: int, output dimension, i.e. the output tensor will have the shape of (batch_size, time_steps, filters)
        kernel_size: int, size of the convolution kernel
        strides: int, convolution step size
        padding: 'same' | 'valid'
    """
    x = Lambda(lambda x: K.expand_dims(x, axis=2))(input_tensor)
    
    x = Conv2DTranspose(filters=filters,
                        kernel_size=(kernel_size, 1),
                        activation=activation,
                        strides=(strides, 1),
                        padding=padding)(x)
    x = Lambda(lambda x: K.squeeze(x, axis=2))(x)
    return x

# %%
input_img = Input(shape=(x_train.shape[1],1))


x = Conv1D(filters=40,kernel_size=16,activation='elu',strides=2,padding='same')(input_img)
x = BatchNormalization()(x)
x = Conv1D(filters=20, kernel_size=16,activation='relu',strides=2,padding='same')(x)
x = BatchNormalization()(x)
x = Conv1D(filters=20, kernel_size=16,activation='elu',strides=2,padding='same')(x)
x = BatchNormalization()(x)
x = Conv1D(filters=20, kernel_size=16,activation='elu',strides=2,padding='same')(x)
x = BatchNormalization()(x)
x = Conv1D(filters=40, kernel_size=16,activation='elu',strides=2,padding='same')(x)
x = BatchNormalization()(x)
x = Conv1D(filters=1, kernel_size=16,activation='elu',strides=1,padding='same')(x)
x = BatchNormalization()(x)


x = Conv1DTranspose(input_tensor=x, filters=1,kernel_size=16, activation='elu',strides=1,padding='same')
x = BatchNormalization()(x)
x = Conv1DTranspose(input_tensor=x,filters=40,kernel_size=16,activation='elu',strides=2,padding='same')
x = BatchNormalization()(x)
x = Conv1DTranspose(input_tensor=x,filters=20,kernel_size=16,activation='elu',strides=2,padding='same')
x = BatchNormalization()(x)
x = Conv1DTranspose(input_tensor=x,filters=20,kernel_size=16,activation='elu',strides=2, padding='same')
x = BatchNormalization()(x)
x = Conv1DTranspose(input_tensor=x,filters=20,kernel_size=16,activation='elu',strides=2,padding='same')
x = BatchNormalization()(x)
x = Conv1DTranspose(input_tensor=x,filters=40,kernel_size=16,activation='elu',strides=2, padding='same')
x = BatchNormalization()(x)
x = Conv1DTranspose(input_tensor=x,filters=1,kernel_size=16,activation='sigmoid',strides=1,padding='same')

autoencoder = Model(input_img, x)
print(autoencoder.summary())
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 1024, 1)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 512, 40)           680
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512, 40)           160
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 256, 20)           12820
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256, 20)           80
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 128, 20)           6420
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128, 20)           80
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 64, 20)            6420
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64, 20)            80
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 32, 40)            12840
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32, 40)            160
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 32, 1)             641
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 32, 1)             4
# _________________________________________________________________
# lambda_1 (Lambda)            (None, 32, 1, 1)          0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 32, 1, 1)          17
# _________________________________________________________________
# lambda_2 (Lambda)            (None, 32, 1)             0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 32, 1)             4
# _________________________________________________________________
# lambda_3 (Lambda)            (None, 32, 1, 1)          0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 64, 1, 40)         680
# _________________________________________________________________
# lambda_4 (Lambda)            (None, 64, 40)            0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 64, 40)            160
# _________________________________________________________________
# lambda_5 (Lambda)            (None, 64, 1, 40)         0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 128, 1, 20)        12820
# _________________________________________________________________
# lambda_6 (Lambda)            (None, 128, 20)           0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 128, 20)           80
# _________________________________________________________________
# lambda_7 (Lambda)            (None, 128, 1, 20)        0
# _________________________________________________________________
# conv2d_transpose_4 (Conv2DTr (None, 256, 1, 20)        6420
# _________________________________________________________________
# lambda_8 (Lambda)            (None, 256, 20)           0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 256, 20)           80
# _________________________________________________________________
# lambda_9 (Lambda)            (None, 256, 1, 20)        0
# _________________________________________________________________
# conv2d_transpose_5 (Conv2DTr (None, 512, 1, 20)        6420
# _________________________________________________________________
# lambda_10 (Lambda)           (None, 512, 20)           0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 512, 20)           80
# _________________________________________________________________
# lambda_11 (Lambda)           (None, 512, 1, 20)        0
# _________________________________________________________________
# conv2d_transpose_6 (Conv2DTr (None, 1024, 1, 40)       12840
# _________________________________________________________________
# lambda_12 (Lambda)           (None, 1024, 40)          0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 1024, 40)          160
# _________________________________________________________________
# lambda_13 (Lambda)           (None, 1024, 1, 40)       0
# _________________________________________________________________
# conv2d_transpose_7 (Conv2DTr (None, 1024, 1, 1)        641
# _________________________________________________________________
# lambda_14 (Lambda)           (None, 1024, 1)           0
# =================================================================
# Total params: 80,787
# Trainable params: 80,223
# Non-trainable params: 564
# _________________________________________________________________
# None

# %%
from keras.optimizers import *

#Adam(lr=0.001, beta_1=0.9, beta_2=0.999, decay=1e-5),


autoencoder.compile(optimizer= Adam(lr=0.001),                    
                               loss='mse')
                               #metrics=['accuracy'])

# %%
from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_loss', mode='min', patience=10)

history = autoencoder.fit(x_train_noisy, x_train,
    epochs = 1000,
    batch_size = 8,
    shuffle = True,
    #validation_split=0.2,
    validation_data=(x_test_noisy, x_test),
    callbacks=[es])
# Out:
# Train on 6086 samples, validate on 1522 samples
# Epoch 1/1000
# 6086/6086 [==============================] - 17s 3ms/step - loss: 0.0094 - val_loss: 1.1965e-05
# Epoch 2/1000
# 6086/6086 [==============================] - 14s 2ms/step - loss: 9.7164e-06 - val_loss: 8.3837e-06
# Epoch 3/1000
# 6086/6086 [==============================] - 14s 2ms/step - loss: 7.6585e-06 - val_loss: 6.9140e-06
# Epoch 4/1000
# 6086/6086 [==============================] - 14s 2ms/step - loss: 6.6870e-06 - val_loss: 6.5885e-06
# Epoch 5/1000
# 6086/6086 [==============================] - 14s 2ms/step - loss: 6.1810e-06 - val_loss: 5.9017e-06
# Epoch 6/1000
# 6086/6086 [==============================] - 14s 2ms/step - loss: 5.9067e-06 - val_loss: 5.9926e-06
# Epoch 7/1000
# 6086/6086 [==============================] - 14s 2ms/step - loss: 5.6943e-06 - val_loss: 5.1546e-06
# Epoch 8/1000
# 6086/6086 [==============================] - 14s 2ms/step - loss: 5.3281e-06 - val_loss: 5.0997e-06
# Epoch 9/1000
# 6086/6086 [==============================] - 14s 2ms/step - loss: 4.3629e-06 - val_loss: 3.8388e-06
# Epoch 10/1000
# 6086/6086 [==============================] - 14s 2ms/step - loss: 3.3063e-06 - val_loss: 2.9297e-06
# Epoch 11/1000
# 6086/6086 [==============================] - 14s 2ms/step - loss: 2.6011e-06 - val_loss: 2.8294e-06
# Epoch 12/1000
# 6086/6086 [==============================] - 14s 2ms/step - loss: 2
1000
# 6086/6086 [==============================] - 14s 2ms/step - loss: 1.7231e-07 - val_loss: 2.0205e-07
# Epoch 96/1000
# 6086/6086 [==============================] - 14s 2ms/step - loss: 1.7168e-07 - val_loss: 1.9914e-07
# Epoch 97/1000
# 6086/6086 [==============================] - 14s 2ms/step - loss: 1.6945e-07 - val_loss: 1.8450e-07
# Epoch 98/1000
# 6086/6086 [==============================] - 14s 2ms/step - loss: 1.6953e-07 - val_loss: 4.0204e-07
# Epoch 99/1000
# 6086/6086 [==============================] - 14s 2ms/step - loss: 1.6937e-07 - val_loss: 2.1441e-07
# Epoch 100/1000
# 6086/6086 [==============================] - 14s 2ms/step - loss: 1.6652e-07 - val_loss: 1.8411e-07
# Epoch 101/1000
# 6086/6086 [==============================] - 14s 2ms/step - loss: 1.6409e-07 - val_loss: 1.9105e-07
# Epoch 102/1000
# 6086/6086 [==============================] - 14s 2ms/step - loss: 1.6472e-07 - val_loss: 3.4376e-07
# Epoch 103/1000
# 6086/6086 [==============================] - 14s 2ms/step - loss: 1.6541e-07 - val_loss: 2.1240e-07
# Epoch 104/1000
# 6086/6086 [==============================] - 14s 2ms/step - loss: 1.6292e-07 - val_loss: 1.9580e-07
# Epoch 105/1000
# 6086/6086 [==============================] - 14s 2ms/step - loss: 1.6141e-07 - val_loss: 1.9349e-07
# Epoch 106/1000
# 6086/6086 [==============================] - 14s 2ms/step - loss: 1.5901e-07 - val_loss: 2.5062e-07
# Epoch 107/1000
# 6086/6086 [==============================] - 14s 2ms/step - loss: 1.5924e-07 - val_loss: 1.9940e-07
# Epoch 108/1000
# 6086/6086 [==============================] - 14s 2ms/step - loss: 1.6028e-07 - val_loss: 2.0490e-07
# Epoch 109/1000
# 6086/6086 [==============================] - 14s 2ms/step - loss: 1.5799e-07 - val_loss: 1.9888e-07
# Epoch 110/1000
# 6086/6086 [==============================] - 14s 2ms/step - loss: 1.5707e-07 - val_loss: 1.9858e-07

# %%
plt.plot(history.history["loss"], label="Training loss")
plt.plot(history.history["val_loss"], label="Validation loss")
plt.legend()

# %%
# plt.plot(history.history["accuracy"], label="Training acc")
# plt.plot(history.history["val_accuracy"], label="Validation acc")
# plt.legend()

# %%
decoded_imgs = autoencoder.predict(x_test_noisy)
decoded_imgs.shape
# Out:
# (1522, 1024, 1)

# %%
x_train_noisy = x_train_noisy.reshape(x_train_noisy.shape[0],
                                      x_train_noisy.shape[1])

decoded_imgs = decoded_imgs.reshape(decoded_imgs.shape[0],
                                    decoded_imgs.shape[1])

x_test = x_test.reshape(x_test.shape[0], x_test.shape[1])

# %%
fig, ax=plt.subplots(figsize=(15,5))
ax.plot(x_test[300], 'b', label='Clean')
ax.plot(decoded_imgs[300], 'k', label='Decoded')   
ax.plot(x_test_noisy[300], 'r', label='Noise')
plt.legend()
plt.show()

# %%
fig, ax=plt.subplots(figsize=(15,5))
ax.plot(x_test[300], 'b')
plt.title('clean_ecg')
plt.show()

# %%
fig, ax=plt.subplots(figsize=(15,5))
ax.plot(x_test_noisy[300], 'r')
plt.title('noise_ecg')
plt.show()

# %%
fig, ax=plt.subplots(figsize=(15,5))
ax.plot(decoded_imgs[300], 'k')   
plt.title('Reconstruction_ecg')
plt.show()

# %%
fig, ax=plt.subplots(figsize=(15,5))
ax.plot(x_test_noisy[300], 'r', label='Noise')
ax.plot(x_test[300], 'b', label='Clean')
plt.legend()
plt.show()

# %%
fig, ax=plt.subplots(figsize=(15,5))
ax.plot(x_test[50], 'b', label='Clean')
ax.plot(decoded_imgs[50], 'k', label='Decoded')   
plt.legend()
plt.show()

# %%
fig, ax=plt.subplots(figsize=(15,5))
ax.plot(x_test_noisy[300], 'r', label='Noise')
ax.plot(decoded_imgs[300], 'k', label='Decoded')   
plt.legend()
plt.show()
